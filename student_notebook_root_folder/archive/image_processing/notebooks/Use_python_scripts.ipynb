# %%
import sys
sys.path.insert(0, '../python_scripts')
import record_video
import apply_face_detection
import adjacent_video
import display_mp4
import barcode

# %%
orig = '../videos/recording4.mp4'
postFD = '../videos/fd4.mp4'
sidebyside = '../videos/split4.mp4'
record_video.record_from_webcam(orig)
apply_face_detection.face_detect_video(orig, postFD)
adjacent_video.adjacent_video(orig, postFD, sidebyside)
# Out:
# 100
# 0
# 40
# 80

# %%
display_mp4.display_mp4(orig)
# Out:
# <video alt="test" controls>
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
display_mp4.display_mp4(postFD)
# Out:
# <video alt="test" controls>
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
display_mp4.display_mp4(sidebyside)
# Out:
# <video alt="test" controls>
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('../test_images/test2.png', 1)
plt.imshow(img, cmap = 'gray')
decoded_objects = barcode.decode(img)
for obj in decoded_objects:
    print(obj.type)
    print(obj.data)
barcode.display(img, decoded_objects)
plt.imshow(img)
# Out:
# Type :  QRCODE
# Data :  b'https://goo.gl/i4csiL'
#
# QRCODE
# b'https://goo.gl/i4csiL'

# %%
img = cv2.imread('../test_images/test3.jpg', 1)
plt.imshow(img, cmap = 'gray')
decoded_objects = barcode.decode(img)
for obj in decoded_objects:
    print(obj.type)
    print(obj.data)
barcode.display(img, decoded_objects)
plt.imshow(img)
# Out:
# Type :  QRCODE
# Data :  b'http://www.scienceabc.com'
#
# QRCODE
# b'http://www.scienceabc.com'

# %%
img = cv2.imread('../test_images/test4.jpg', 1)
plt.imshow(img, cmap = 'gray')
decoded_objects = barcode.decode(img)
for obj in decoded_objects:
    print(obj.type)
    print(obj.data)
barcode.display(img, decoded_objects)
plt.imshow(img)
# Out:
# Type :  QRCODE
# Data :  b'http://socialqrcode.com/code/763108/Social/'
#
# QRCODE
# b'http://socialqrcode.com/code/763108/Social/'

# %%
img = cv2.imread('../test_images/test5.jpg', 1)
plt.imshow(img, cmap = 'gray')
decoded_objects = barcode.decode(img)
for obj in decoded_objects:
    print(obj.type)
    print(obj.data)
barcode.display(img, decoded_objects)
plt.imshow(img)
# Out:
# Type :  CODE128
# Data :  b'00123456789101112133'
#
# CODE128
# b'00123456789101112133'

# %%
img = cv2.imread('../test_images/test6.png', 1)
plt.imshow(img, cmap = 'gray')
decoded_objects = barcode.decode(img)
for obj in decoded_objects:
    print(obj.type)
    print(obj.data)
barcode.display(img, decoded_objects)
plt.imshow(img)
# Out:
# Type :  EAN13
# Data :  b'9781234567897'
#
# EAN13
# b'9781234567897'

# %%
img = cv2.imread('../test_images/many_barcodes.png', 1)
plt.imshow(img, cmap = 'gray')
decoded_objects = barcode.decode(img)
for obj in decoded_objects:
    print(obj.type)
    print(obj.data)
barcode.display(img, decoded_objects)
plt.imshow(img)
# Out:
# Type :  I25
# Data :  b'0123456789'
#
# Type :  EAN8
# Data :  b'01234565'
#
# Type :  CODE39
# Data :  b'ABC123'
#
# Type :  EAN13
# Data :  b'0012345678905'
#
# Type :  EAN13
# Data :  b'0012345000065'
#
# I25
# b'0123456789'
# EAN8
# b'01234565'
# CODE39
# b'ABC123'
# EAN13
# b'0012345678905'
# EAN13
# b'0012345000065'
